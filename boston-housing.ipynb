# %% [markdown]
# # Short Assignment 2
#
# This is an individual assignment.
#
# **Due: Friday, January 28 @ 11:59 PM**

# %% [markdown]
# ## Objectives
#
# * Login and create jobs in supercomputer HiPerGator
# * Practice command line instructions
# * Integrate and practice Git within HiPerGator
# * Understand and implement Linear Regression on datasets already in the feature space

# %% [markdown]
# ## Setup
#
# During the info session about HiPerGator, you learned that for each HiPerGator SLURM job we need to specify three components:
#
# * Time in hours (how long will be needed to complete the job)
# * Computing power (number of CPUs and/or GPUs)
# * Memory (how much RAM should be reserved to execute a batch file)
#
# Follow the next short tutorials:
#
#
# ### 1. Open OnDemand
# Follow the following sets:
#
# 1. Login to HiPerGator using the web interface [Open OnDemand](https://ood.rc.ufl.edu). Remember that Open OnDemand is only accessible within the UF Network so you need to connect to UF's VPN (see OOD's [help page](https://help.rc.ufl.edu/doc/Open_OnDemand) for more details).
#
# 2. On the top left bar, click on "Files" and then "/blue/eee4773"
#
# 3. Make sure you are able to see your directory in the blue storage (path ```/blue/eee4773/```). If you do not see a directory with your Gatorlink username, create one by clicking "New Dir" on the top bar.
#
# 4. Make sure that your directory is in private mode, that is, only you have access to its contents. To do this, click on "Open in Terminal", type ```chmod 700 Gatorlink_username``` (for example, for me this would look like ```chmod 700 catiaspsilva```) and hit Enter.
#
# 5. Within the blue storage location (```/blue/eee4773/```) you will also find a folder called *share* (path is ```/blue/eee4773/share/```). This is where I will upload the training data for the project along with any other relevant materials available to everyone. You will then be able to load the data from this directory instead of having to push it to your directory, which would take up unnecessary space from your 2TB blue storage.
#
# 6. Explore how to create a using OOD. Go back to the dashboard (https://ood.rc.ufl.edu). Select "Interactive Apps" and then the server "Jupyter Notebook". Then you will see a form with the SLURM options available for that application. Select the first box if you prefer to use JupyterLab instead of Jupyter Notebooks. Utilize the [OOD's help page](https://help.rc.ufl.edu/doc/Open_OnDemand) (section "General Form Fields") to populate each field with the recommended values. Launch Jupyter.
#
# ### 2. Token Authentication for Git Operations
#
# A [new change to Git policies was established in August 13, 2021](https://github.blog/2020-12-15-token-authentication-requirements-for-git-operations/), where Git will no longer accept account passwords when authenticating Git operations on GitHub.com. Instead you will need to use a token authorization. These steps will help you set this token.
#
# 1. Open your GitHub account (https://github.com/username).
#
# 2. On the top right, click on your avatar and then click "Settings".
#
# 3. On the left bar select "Developer Settings" and then "Personal Access Tokens".
#
# 4. Click on "Generate new token". Give a name to this token, for example, "HiPerGator" and define an expiration date (suggestion: until end of semester, Dec 22). Select all scopes or customize as you wish. Create token.
#
# 5. This will display a personal access token. You must copy this token and save it somewhere password protected. This token will not be visible when you come back to this page.
#
#
# ### 3. Jupyter Hub
#
# 1. Open Jupyter Hub or [JHub](https://jhub.rc.ufl.edu/). Remember that JHub is only accessible within the UF Network so you need to connect to UF's VPN (see [JHub's help page](https://help.rc.ufl.edu/doc/JupyterHub) for more details).
#
# 2. Select job profile "Teaching - 1 CPU core, 2GB RAM, 2h". This automatically creates a SLURM form with these specs.
#
# 3. This should launch a Jupyter server within your blue storage directory "/eee4773/Gatorlink/". Click on path "/eee4773/. This should change the directory to our class cluster and you should only have access to your directory "/eee4773/Gatorlink/" and the shared directory "/eee4773/share/". Click again in your "Gatorlink" directory.
#
# 4. Clone your Short Assignment 2 repository within your directory. On the left bar, click on the Git icon (3rd counting from top). Then click "Clone Repository", paste your git repo (https://github.com/Fundamentals-of-Machine-Learning-F21/your_repo.git) and click "Clone".
#
# 5. Enter your GitHub username and the personal token created above.
#
# 6. SA2 repo should now be visible within your blue storage directory.
#
# 7. To open the SA2 Jupyter Notebook, right-click on this file and select "Open with > Notebook". By default, this will launch Jupyter with a Python 3 kernel (see top right corner). If you wish to change to a tensorflow or pytorch kernel, you can click on "Python 3 (ipykernel)" and change it to one of the provided options.
#
# ### 4. ```commit``` and ```push``` changes
#
# 1. Once you complete your work, make sure to save the file/s.
#
# 2. Click on the git icon on the left bar. This will display a list of changed files (any new notebooks or edits made) and untracked files (typically Jupyter auto-generated checkpoints). On the "changed" file called "Short Assignment 2", click on the ```+``` sign, this will stage the file ready for commit.
#
# 3. Add a commit message in the "Summary" box and, if you wish, any additional comments in the "Description" box. Then click ```commit```.
#
# 4. On the top you should be the ```push``` cloud with an orange icon illustrating that there are committed files ready to ```push``` to Github. Click on push committed changes, enter your GitHub username and your personal token from earlier. If all is good, you should receive a notification "successfully pushed" in the bottom right of your screen.
#
# 5. Alternatively, you can use the command line to commit and push changes. Make more edits to the file and save it. Then within your SA2 directory ("/eee4773/Gatorlink/SA2-directory/") click on the ```+``` icon to launch the launcher and select "Terminal" from section "Other". Then follow Git Bash commands to ```add```, ```commit``` and ```push``` changes:
#     * ```git add "filename.ipynb"``` (repeat this line for all files to be added to the staging area)
#     * ```git commit -m "add a commit message here"```
#     * ```git push```
#     * Enter your GitHub username
#     * Paste your Personal Token (note that it will not show characters for security reasons, just hit Enter)
#     * All done!

# %% [markdown]
# # Assignment Description

# %% [markdown]
# ## Problem 1
#
# **Clone SA2 repository in HiPerGator directory:** clone your SA2 repository within your directory. Select your SA2 directory (path /eee4773/Gatorlink/SA2-repo/), and click on the Git icon. Take a screenshot of this page and include it in your repo.

# %% [markdown]
# ## Problem 2
#
# In this problem you will be working with the **Boston Housing Prices Data Set**. Each record in the database describes a Boston suburb or town. The data was drawn from the Boston Standard Metropolitan Statistical Area (SMSA) in 1970. The attributes are defined as follows:

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %%
data = load_boston(return_X_y=False)

print(data.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %% [markdown]
# The goal of this assignment is to design a **Linear Regression model** that predicts the median value of owner-occupied homes (value in \$1,000s) using the attributes for each sample.
#
# To simplify this problem, the line below creates a ```pandas``` dataframe with all the attributes and target value:

# %%
# df - dataframe
df = pd.DataFrame(np.hstack((data.data,data.target[:,np.newaxis])),
                  columns=np.hstack((data.feature_names,['House Value'])))
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  House Value
# 0       15.3  396.90   4.98         24.0
# 1       17.8  396.90   9.14         21.6
# 2       17.8  392.83   4.03         34.7
# 3       18.7  394.63   2.94         33.4
# 4       18.7  396.90   5.33         36.2
# ..       ...     ...    ...          ...
# 501     21.0  391.99   9.67         22.4
# 502     21.0  396.90   9.08         20.6
# 503     21.0  396.90   5.64         23.9
# 504     21.0  393.45   6.48         22.0
# 505     21.0  396.90   7.88         11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# Use this ```pandas``` dataframe to access the appropriate data entries to solve the following problems:
#
# 1. Using ```pandas``` methods do:
#     * Print a [correlation matrix](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) and comment on each feature's predictive value
#     * [Plot the ```scatter_matrix```](https://pandas.pydata.org/docs/reference/api/pandas.plotting.scatter_matrix.html) for each pair of variables. This may aid your analysis in step 1.
#     * Based on these measures, provide a paragraph description about which features have higher predictive value? You can use Pearson's correlation coefficient as a measure of predictive value. Justify your answer.
#     * Choose the top feature with largest predictive value. Justify your answer.

# %%
pearsoncorr = df.corr(method = 'pearson')
pearsoncorr
# Out:
#                  CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM         1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN          -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS        0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS        -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX          0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM          -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE          0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS         -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD          0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX          0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PTRATIO      0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B           -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# LSTAT        0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808
# House Value -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360
#
#                   AGE       DIS       RAD       TAX   PTRATIO         B  \
# CRIM         0.352734 -0.379670  0.625505  0.582764  0.289946 -0.385064
# ZN          -0.569537  0.664408 -0.311948 -0.314563 -0.391679  0.175520
# INDUS        0.644779 -0.708027  0.595129  0.720760  0.383248 -0.356977
# CHAS         0.086518 -0.099176 -0.007368 -0.035587 -0.121515  0.048788
# NOX          0.731470 -0.769230  0.611441  0.668023  0.188933 -0.380051
# RM          -0.240265  0.205246 -0.209847 -0.292048 -0.355501  0.128069
# AGE          1.000000 -0.747881  0.456022  0.506456  0.261515 -0.273534
# DIS         -0.747881  1.000000 -0.494588 -0.534432 -0.232471  0.291512
# RAD          0.456022 -0.494588  1.000000  0.910228  0.464741 -0.444413
# TAX          0.506456 -0.534432  0.910228  1.000000  0.460853 -0.441808
# PTRATIO      0.261515 -0.232471  0.464741  0.460853  1.000000 -0.177383
# B           -0.273534  0.291512 -0.444413 -0.441808 -0.177383  1.000000
# LSTAT        0.602339 -0.496996  0.488676  0.543993  0.374044 -0.366087
# House Value -0.376955  0.249929 -0.381626 -0.468536 -0.507787  0.333461
#
#                 LSTAT  House Value
# CRIM         0.455621    -0.388305
# ZN          -0.412995     0.360445
# INDUS        0.603800    -0.483725
# CHAS        -0.053929     0.175260
# NOX          0.590879    -0.427321
# RM          -0.613808     0.695360
# AGE          0.602339    -0.376955
# DIS         -0.496996     0.249929
# RAD          0.488676    -0.381626
# TAX          0.543993    -0.468536
# PTRATIO      0.374044    -0.507787
# B           -0.366087     0.333461
# LSTAT        1.000000    -0.737663
# House Value -0.737663     1.000000

# %%
pd.plotting.scatter_matrix(pearsoncorr, alpha = 1, figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='CRIM', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='NOX', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='RM', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='AGE', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='DIS', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='RAD', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='TAX', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='B', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='House Value', ylabel='CRIM'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='ZN'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='ZN'>,
#         <AxesSubplot:xlabel='NOX', ylabel='ZN'>,
#         <AxesSubplot:xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='AGE', ylabel='ZN'>,
#         <AxesSubplot:xlabel='DIS', ylabel='ZN'>,
#         <AxesSubplot:xlabel='RAD', ylabel='ZN'>,
#         <AxesSubplot:xlabel='TAX', ylabel='ZN'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='ZN'>,
#         <AxesSubplot:xlabel='B', ylabel='ZN'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='ZN'>,
#         <AxesSubplot:xlabel='House Value', ylabel='ZN'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='ZN', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='NOX', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='RM', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='AGE', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='DIS', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='RAD', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='TAX', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='B', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='INDUS'>,
#         <AxesSubplot:xlabel='House Value', ylabel='INDUS'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='ZN', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='NOX', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='RM', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='AGE', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='DIS', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='RAD', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='TAX', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='B', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='CHAS'>,
#         <AxesSubplot:xlabel='House Value', ylabel='CHAS'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='NOX'>,
#         <AxesSubplot:xlabel='ZN', ylabel='NOX'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='NOX'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='NOX'>,
#         <AxesSubplot:xlabel='NOX', ylabel='NOX'>,
#         <AxesSubplot:xlabel='RM', ylabel='NOX'>,
#         <AxesSubplot:xlabel='AGE', ylabel='NOX'>,
#         <AxesSubplot:xlabel='DIS', ylabel='NOX'>,
#         <AxesSubplot:xlabel='RAD', ylabel='NOX'>,
#         <AxesSubplot:xlabel='TAX', ylabel='NOX'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='NOX'>,
#         <AxesSubplot:xlabel='B', ylabel='NOX'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='NOX'>,
#         <AxesSubplot:xlabel='House Value', ylabel='NOX'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='RM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RM'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='RM'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='RM'>,
#         <AxesSubplot:xlabel='NOX', ylabel='RM'>,
#         <AxesSubplot:xlabel='RM', ylabel='RM'>,
#         <AxesSubplot:xlabel='AGE', ylabel='RM'>,
#         <AxesSubplot:xlabel='DIS', ylabel='RM'>,
#         <AxesSubplot:xlabel='RAD', ylabel='RM'>,
#         <AxesSubplot:xlabel='TAX', ylabel='RM'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='RM'>,
#         <AxesSubplot:xlabel='B', ylabel='RM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RM'>,
#         <AxesSubplot:xlabel='House Value', ylabel='RM'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='AGE'>,
#         <AxesSubplot:xlabel='ZN', ylabel='AGE'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='AGE'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='AGE'>,
#         <AxesSubplot:xlabel='NOX', ylabel='AGE'>,
#         <AxesSubplot:xlabel='RM', ylabel='AGE'>,
#         <AxesSubplot:xlabel='AGE', ylabel='AGE'>,
#         <AxesSubplot:xlabel='DIS', ylabel='AGE'>,
#         <AxesSubplot:xlabel='RAD', ylabel='AGE'>,
#         <AxesSubplot:xlabel='TAX', ylabel='AGE'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='AGE'>,
#         <AxesSubplot:xlabel='B', ylabel='AGE'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='AGE'>,
#         <AxesSubplot:xlabel='House Value', ylabel='AGE'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='DIS'>,
#         <AxesSubplot:xlabel='ZN', ylabel='DIS'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='DIS'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='DIS'>,
#         <AxesSubplot:xlabel='NOX', ylabel='DIS'>,
#         <AxesSubplot:xlabel='RM', ylabel='DIS'>,
#         <AxesSubplot:xlabel='AGE', ylabel='DIS'>,
#         <AxesSubplot:xlabel='DIS', ylabel='DIS'>,
#         <AxesSubplot:xlabel='RAD', ylabel='DIS'>,
#         <AxesSubplot:xlabel='TAX', ylabel='DIS'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='DIS'>,
#         <AxesSubplot:xlabel='B', ylabel='DIS'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='DIS'>,
#         <AxesSubplot:xlabel='House Value', ylabel='DIS'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='RAD'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RAD'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='RAD'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='RAD'>,
#         <AxesSubplot:xlabel='NOX', ylabel='RAD'>,
#         <AxesSubplot:xlabel='RM', ylabel='RAD'>,
#         <AxesSubplot:xlabel='AGE', ylabel='RAD'>,
#         <AxesSubplot:xlabel='DIS', ylabel='RAD'>,
#         <AxesSubplot:xlabel='RAD', ylabel='RAD'>,
#         <AxesSubplot:xlabel='TAX', ylabel='RAD'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='RAD'>,
#         <AxesSubplot:xlabel='B', ylabel='RAD'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RAD'>,
#         <AxesSubplot:xlabel='House Value', ylabel='RAD'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='TAX'>,
#         <AxesSubplot:xlabel='ZN', ylabel='TAX'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='TAX'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='TAX'>,
#         <AxesSubplot:xlabel='NOX', ylabel='TAX'>,
#         <AxesSubplot:xlabel='RM', ylabel='TAX'>,
#         <AxesSubplot:xlabel='AGE', ylabel='TAX'>,
#         <AxesSubplot:xlabel='DIS', ylabel='TAX'>,
#         <AxesSubplot:xlabel='RAD', ylabel='TAX'>,
#         <AxesSubplot:xlabel='TAX', ylabel='TAX'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='TAX'>,
#         <AxesSubplot:xlabel='B', ylabel='TAX'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='TAX'>,
#         <AxesSubplot:xlabel='House Value', ylabel='TAX'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='ZN', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='NOX', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='RM', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='AGE', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='DIS', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='RAD', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='TAX', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='B', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='PTRATIO'>,
#         <AxesSubplot:xlabel='House Value', ylabel='PTRATIO'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='B'>,
#         <AxesSubplot:xlabel='ZN', ylabel='B'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='B'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='B'>,
#         <AxesSubplot:xlabel='NOX', ylabel='B'>,
#         <AxesSubplot:xlabel='RM', ylabel='B'>,
#         <AxesSubplot:xlabel='AGE', ylabel='B'>,
#         <AxesSubplot:xlabel='DIS', ylabel='B'>,
#         <AxesSubplot:xlabel='RAD', ylabel='B'>,
#         <AxesSubplot:xlabel='TAX', ylabel='B'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='B'>,
#         <AxesSubplot:xlabel='B', ylabel='B'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='B'>,
#         <AxesSubplot:xlabel='House Value', ylabel='B'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='ZN', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='NOX', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='AGE', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='DIS', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RAD', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='TAX', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='B', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='House Value', ylabel='LSTAT'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='House Value'>,
#         <AxesSubplot:xlabel='ZN', ylabel='House Value'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='House Value'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='House Value'>,
#         <AxesSubplot:xlabel='NOX', ylabel='House Value'>,
#         <AxesSubplot:xlabel='RM', ylabel='House Value'>,
#         <AxesSubplot:xlabel='AGE', ylabel='House Value'>,
#         <AxesSubplot:xlabel='DIS', ylabel='House Value'>,
#         <AxesSubplot:xlabel='RAD', ylabel='House Value'>,
#         <AxesSubplot:xlabel='TAX', ylabel='House Value'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='House Value'>,
#         <AxesSubplot:xlabel='B', ylabel='House Value'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='House Value'>,
#         <AxesSubplot:xlabel='House Value', ylabel='House Value'>]],
#       dtype=object)

# %% [markdown]
# The correlation coeffecient, of say X and Y, ranges from -1 to +1. Correlation coeffecient which takes value less than 0 means that X and Y are negatively correlated and if it takes value more than 0, X and Y are positively correlated. If the correlation coeffecient is 0, then X and Y are uncorrelated. We would like to focus on correlation coeffecients whose absolute value is closer to 1 to maximise our predictions.
#
# Lets fix a correlation threshold of 50%.
#
# According to the above matrix and correlation threshold,
# 1.  CRIM    and House value are poorly correlated
# 2.  ZN      and House value are poorly correlated
# 3.  INDUS   and House value are poorly correlated
# 4.  CHAS    and House value are poorly correlated
# 5.  NOX     and House value are poorly correlated
# 6.  RM      and House value are correlated well
# 7.  AGE     and House value are poorly correlated
# 8.  DIS     and House value are poorly correlated
# 9.  RAD     and House value are poorly correlated
# 10. TAX     and House value are poorly correlated
# 11. PTRATIO and House value are correlated well
# 12. B       and House value are poorly correlated
# 13. LSTAT   and House value are correlated well
#
# Out of the features, RM, PTRATIO and LSTAT have correlation with House value greater than 50% i.e. the absolute value of their correlation coeffecient is greater than 0.5.
#
# The top feature is LSTAT since it has the highest absolute correlation coeffeceint of 0.737663. Hence this feature has the most predictive value.

# %%
lstat = df['LSTAT'].to_numpy()
hv = df['House Value'].to_numpy()

# %% [markdown]
# 2. Normalize the selected feature using the min-max scaling method. Let $x_1$ be one of the selected feature:
#
# $$\hat{x_1} = \frac{x_1 - \min(x_1)}{\max(x_1) - \min(x_1)}$$
#
# where $\max(x_1)$ is the maximum value of feature $x_1$ and $\min(x_1)$ is the minimum value of feature $x_1$.

# %%
n_lstat = ( lstat - min(lstat) ) / (max(lstat) - min(lstat))

# %% [markdown]
# 3. Implement a polynomial regression model using 4-fold cross-validation to select the best model order $M$. Use the coefficient of determination, $r^2$, as the goodness measure.
#
# You should **not** use built-in functions to implement polynomial regression or cross-validation. But you can use help functions such as [```train_test_split```](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) to split the data, [```linregress```](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html) to compute the coefficient of determination and [```KFold```](https://scikit-learn.org/0.16/modules/generated/sklearn.cross_validation.KFold.html) to split the training set in k-folds.
#
# * partition the (scaled) data into training (80%) and test (20%) sets
# * use 4-fold cross-validation to select a best value for model order $M$ from a pre-defined set
# * train a final model with the *best* model order
# * evaluate performance in the test set using the same goodness measure ($r^2$)
# * draw conclusions

# %%
def PolynomialRegression(x,t,M):
    X = np.array([x**m for m in range(M+1)]).T 
    w = np.linalg.inv(X.T@X)@X.T@t
    y = X@w
    error = t-y
    return w, y, error

def PolynomialRegression_test(x,M,w):
    X = np.array([x**m for m in range(M+1)]).T 
    y = X@w
    return y

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
#partition the (scaled) data into training (80%) and test (20%) sets

lstat_Train, lstat_Test, hv_Train, hv_Test = train_test_split(n_lstat, hv, test_size = 0.2, random_state = 50)

# %%
#use 4-fold cross-validation to select a best value for model order M from a pre-defined set

k = 4
M = np.arange(1,11,1)
kf = KFold(n_splits = k, shuffle = True)

# %%
R_avg=[]
for i in M:
    print('M = ',i)
    f = 1
    r_avg = 0
    for train_index, val_index in kf.split(lstat_Train):
        print('\nFold ',f)
        lstat_train, lstat_val = lstat_Train[train_index], lstat_Train[val_index]
        hv_train, hv_val = hv_Train[train_index], hv_Train[val_index]
        w, trained, _ = PolynomialRegression(lstat_train, hv_train, i)
        valed = PolynomialRegression_test(lstat_val, i, w)
        _, _, r, _, _ = linregress(np.sort(hv_val), np.sort(valed))
        r_avg = r_avg + r**2
        print('Coeffecient of determination =',r**2)
        f+=1
    R_avg.append(r_avg/k)
    print('\nAvg coeffecient of determination =',r_avg/k)
    print('-----------------------------------------------------')
print(R_avg)
# Out:
# M =  1
#
# Fold  1
# Coeffecient of determination = 0.7226036368131682
#
# Fold  2
# Coeffecient of determination = 0.7518007539804072
#
# Fold  3
# Coeffecient of determination = 0.8190430914119
#
# Fold  4
# Coeffecient of determination = 0.7471594244669172
#
# Avg coeffecient of determination = 0.7601517266680982
# -----------------------------------------------------
# M =  2
#
# Fold  1
# Coeffecient of determination = 0.8859853753011817
#
# Fold  2
# Coeffecient of determination = 0.8414375952601933
#
# Fold  3
# Coeffecient of determination = 0.9137340888344996
#
# Fold  4
# Coeffecient of determination = 0.8687092292691534
#
# Avg coeffecient of determination = 0.877466572166257
# -----------------------------------------------------
# M =  3
#
# Fold  1
# Coeffecient of determination = 0.8714266997407223
#
# Fold  2
# Coeffecient of determination = 0.9630869298262037
#
# Fold  3
# Coeffecient of determination = 0.8936701867716047
#
# Fold  4
# Coeffecient of determination = 0.9081407561782359
#
# Avg coeffecient of determination = 0.9090811431291916
# -----------------------------------------------------
# M =  4
#
# Fold  1
# Coeffecient of determination = 0.9719287301651377
#
# Fold  2
# Coeffecient of determination = 0.9666916690824927
#
# Fold  3
# Coeffecient of determination = 0.9645816722676345
#
# Fold  4
# Coeffecient of determination = 0.9336868066011417
#
# Avg coeffecient of determination = 0.9592222195291016
# -----------------------------------------------------
# M =  5
#
# Fold  1
# Coeffecient of determination = 0.9548417230008192
#
# Fold  2
# Coeffecient of determination = 0.9732358683184654
#
# Fold  3
# Coeffecient of determination = 0.9769417743620481
#
# Fold  4
# Coeffecient of determination = 0.9319186305610585
#
# Avg coeffecient of determination = 0.9592344990605978
# -----------------------------------------------------
# M =  6
#
# Fold  1
# Coeffecient of determination = 0.9554786477035284
#
# Fold  2
# Coeffecient of determination = 0.9373306932569455
#
# Fold  3
# Coeffecient of determination = 0.9729168379216481
#
# Fold  4
# Coeffecient of determination = 0.9741211475831095
#
# Avg coeffecient of determination = 0.9599618316163079
# -----------------------------------------------------
# M =  7
#
# Fold  1
# Coeffecient of determination = 0.9622745707228264
#
# Fold  2
# Coeffecient of determination = 0.9845814858219665
#
# Fold  3
# Coeffecient of determination = 0.9557063387887289
#
# Fold  4
# Coeffecient of determination = 0.9415005861811901
#
# Avg coeffecient of determination = 0.961015745378678
# -----------------------------------------------------
# M =  8
#
# Fold  1
# Coeffecient of determination = 0.9536394655105518
#
# Fold  2
# Coeffecient of determination = 0.9623591863267672
#
# Fold  3
# Coeffecient of determination = 0.9414875982478058
#
# Fold  4
# Coeffecient of determination = 0.9619402462270134
#
# Avg coeffecient of determination = 0.9548566240780345
# -----------------------------------------------------
# M =  9
#
# Fold  1
# Coeffecient of determination = 0.9796426326437285
#
# Fold  2
# Coeffecient of determination = 0.976778927330502
#
# Fold  3
# Coeffecient of determination = 0.9719480417393067
#
# Fold  4
# Coeffecient of determination = 0.9199773181943594
#
# Avg coeffecient of determination = 0.9620867299769742
# -----------------------------------------------------
# M =  10
#
# Fold  1
# Coeffecient of determination = 0.9680225453038485
#
# Fold  2
# Coeffecient of determination = 0.7374850542625138
#
# Fold  3
# Coeffecient of determination = 0.9832287178852261
#
# Fold  4
# Coeffecient of determination = 0.9660131069667005
#
# Avg coeffecient of determination = 0.9136873561045722
# -----------------------------------------------------
# [0.7601517266680982, 0.877466572166257, 0.9090811431291916, 0.9592222195291016, 0.9592344990605978, 0.9599618316163079, 0.961015745378678, 0.9548566240780345, 0.9620867299769742, 0.9136873561045722]

# %%
print('Optimal model order =', 1 + R_avg.index(max(R_avg)))
# Out:
# Optimal model order = 9

# %%
#train a final model with the best model order
#evaluate performance in the test set using the same goodness measure (r^2)

M_opt = 1 + R_avg.index(max(R_avg))
w_opt, trained_opt, _ = PolynomialRegression(lstat_Train, hv_Train, M_opt)
tested = PolynomialRegression_test(lstat_Test, M_opt, w_opt)
_, _, r_opt, _, _ = linregress(np.sort(hv_Test), np.sort(tested))
print('Coeffecient of Determination =',r_opt**2)
# Out:
# Coeffecient of Determination = 0.9719149520494849

# %%
#fig = plt.figure(figsize=(15,5))
plt.plot(M,R_avg, 'k*-')
plt.xticks(M);

# %%
#draw conclusions

# %% [markdown]
# The coeffecient of determination for M = 9 in cross-validation stage is 0.9620867299769742, the coeffecient of determination for M = 9 by evaluating the actual test set is 0.9719149520494849. The actual prediction model peforms better than the cross validation model which can be confirmed by the values of the corresponding coeffecients of determination.
#
# However, from the above plot we can clearly infer that M = 4, 5, 6, 7 perform similar to M = 9. Therefore it is optimal to M = 4 as the model order to reduce the system complexity.

# %% [markdown]
# # Submit Your Solution
#
# Confirm that you've successfully completed the assignment.
#
# Along with the Notebook, include a PDF of the notebook with your solutions.
#
# ```add``` and ```commit``` the final version of your work, and ```push``` your code to your GitHub repository.
#
# Submit the URL of your GitHub Repository as your assignment submission on Canvas.
